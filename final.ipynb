# %%
import numpy as np
import pandas as pd

# %%
rawdata = pd.read_csv("./Family Income and Expenditure.csv")
rawdata
# Out:
#        Total Household Income              Region  Total Food Expenditure  \
# 0                      480332                 CAR                  117848
# 1                      198235                 CAR                   67766
# 2                       82785                 CAR                   61609
# 3                      107589                 CAR                   78189
# 4                      189322                 CAR                   94625
# 5                      152883                 CAR                   73326
# 6                      198621                 CAR                  104644
# 7                      134961                 CAR                   95644
# 8                      171152                 CAR                   67348
# 9                      625753                 CAR                  158721
# 10                     147005                 CAR                   79530
# 11                     253130                 CAR                  111250
# ...
